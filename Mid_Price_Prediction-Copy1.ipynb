# %% [markdown]
# ## Using LSTMs to Predict Mid-Price Movement from the Limit Order Book
#
# - The goal of this notebook is to predict whether the mid-price will decrease, stay the same, or increase during the next tick. This is accomplished through the usage of an LSTM in tensorflow.

# %% [markdown]
# ### Import the necessary packages

# %%
# %matplotlib inline
from ml_analysis import MLOperator, MLEvaluator, get_LSTM_data
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import json
import time
import tensorflow as tf
from tensorflow.contrib import rnn
from sklearn.metrics import f1_score
# Out:
# /Users/macbook/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Prepare the data

# %%
df = pd.read_csv('INTC_0_1_Megan.csv')
train_weight = 0.8
split = int(len(df)*train_weight)
df_train = df[:split]
df_test = df[split:]
operator = MLOperator()
n_steps = 20
use_features = ['ask_price_1','ask_vol_1','bid_price_1','bid_vol_1','liq_imb_1','liq_imb_2','mid_price_inv_vol_weighted','relative_mid_price_trend','relative_spread','lastest_trade_price','effective_spread']
y_train = df_train.label
sampled_idx = operator.get_samples_index(y_train.iloc[n_steps-1:], 'min')
x_train = df_train[use_features]
y_test = df_test.label.iloc[n_steps-1:]
x_test = df_test[use_features]
x_train, y_train, x_test, y_test = get_LSTM_data(x_train, y_train, x_test, y_test, sampled_idx, n_steps)
nrow = 3000
x_valid = x_test[0:nrow]
y_valid = y_test[0:nrow]
x_test = x_test[nrow:]
y_test = y_test[nrow:]
#print (x_train.shape,y_train.shape,x_test.shape,y_test.shape, x_valid.shape, y_valid.shape)

# %% [markdown]
# ### Set the parameters

# %%
# Training Parameters
learning_rate = 0.001
n_epoch = 5000
n_batch = 500
display_step = 100

# Network Parameters
num_input = x_train.shape[-1] # number of features
timesteps = n_steps # timesteps
num_hidden = 6 # hidden layer num of features
num_classes = 3 # up, down and no-movement

# tf Graph input
# the input variables are first define as placeholder
# a placeholder is a variable/data which will be assigned later
X = tf.placeholder("float", [None, timesteps, num_input]) #dim: batch_size, number of time steps, number of inputs
Y = tf.placeholder("float", [None, num_classes])#dim:batch_size, number of classes (10 here)

#initialize the weigths with a normal random law initialization

weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %% [markdown]
# ### Define the RNN

# %%
def RNN(x, weights, biases):
    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # 1-layer LSTM with num_hidden units
    rnn_cell = rnn.BasicLSTMCell(num_hidden)
    
    # 2-layer LSTM, each layer has num_hidden units. And you can wrap more layers together by doing list comprehension.
    #rnn_cell = rnn.MultiRNNCell([rnn.LSTMCell(num_hidden),rnn.LSTMCell(num_hidden)])

    # Get rnn cell output
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # (1) Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %% [markdown]
# ### Define the loss and optimzation

# %%
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)
#define the loss 
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)
#tf.equal: Returns the truth value of (x == y) element-wise.
#tf.cast: Casts a tensor to a new type. --- here it casts from boolean to float
#tf.argmax:Returns the index with the largest value across axes of a tensor. --- here along the axis of the vector

correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-5-f387354dee2a>:5: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ### Run the model

# %%
# Start training
with tf.Session() as sess:
    
    start_time = time.time()
    
    #please, make sure you changed for your own path 
    log_files_path = '/Users/macbook/Desktop/DLFall2018/codes/DL project/tensorflow-master/logs'
    
    #save and restore variables to and from checkpoints.
    saver = tf.train.Saver()

    # Run the initializer
    sess.run(init)
    
    #will work with this later
    #saver.restore(sess, log_files_path+'multi_layer/model-checkpoint-66000')
    
    loss_trace = []
    
    num_examples = x_train.shape[0]

    # Training cycle
    for epoch in range(n_epoch):
        
        avg_cost = 0.
        total_batch = int(num_examples/n_batch)
        
        # Shuffle the data
        perm = np.arange(num_examples)
        np.random.shuffle(perm)
        x_train = x_train[perm]
        y_train = y_train[perm]
                    
        # Loop over all batches
        for i in range(total_batch):
            
            minibatch_x, minibatch_y = x_train[i*n_batch:(i+1)*n_batch], y_train[i*n_batch:(i+1)*n_batch]

            #minibatch_x, minibatch_y = mnist.train.next_batch(batch_size)
            
            # Fit training using batch data
            #the training is done using the training dataset
            sess.run(train_op, feed_dict={X: minibatch_x, Y: minibatch_y})
            # Compute average loss
            avg_cost += sess.run(loss_op, feed_dict={X: minibatch_x, Y: minibatch_y})/total_batch
        
        # Display logs per epoch step
        if epoch % display_step == 0:
                    
            #the accuracy is evaluated using the validation dataset
            train_acc = sess.run(accuracy, feed_dict={X: x_train, Y: y_train})
            val_cost = sess.run(loss_op, feed_dict={X: x_valid, Y: y_valid})
            acc = sess.run(accuracy, feed_dict={X: x_valid, Y: y_valid})
            loss_trace.append(1-acc)    
            print("Epoch:", '%04d' % (epoch+1), "train_loss :", "{:0.4f}".format(avg_cost), "train_acc :", "{:0.4f}".format(train_acc), \
                  "val_loss :", "{:0.4f}".format(val_cost), "val_acc :", "{:0.4f}".format(acc))    
    
    #save to use later
    saver.save(sess, log_files_path+'DL_Project/lstm-checkpoint')
    
    print("Optimization Finished!")
    #accuracy evaluated with the whole test dataset
    acc = sess.run(accuracy, feed_dict={X: x_test, Y: y_test})
    print("Test Accuracy:", acc)
                    
    elapsed_time = time.time() - start_time
    print('Execution time (seconds) was %0.3f' % elapsed_time)
# Out:
# Epoch: 0001 train_loss : 2.1084 train_acc : 0.3333 val_loss : 0.2353 val_acc : 0.9970
# Epoch: 0101 train_loss : 0.6503 train_acc : 0.7400 val_loss : 0.3295 val_acc : 0.8897
# Epoch: 0201 train_loss : 0.5660 train_acc : 0.7654 val_loss : 0.3003 val_acc : 0.8150
# Epoch: 0301 train_loss : 0.5432 train_acc : 0.7713 val_loss : 0.2919 val_acc : 0.8223
# Epoch: 0401 train_loss : 0.5442 train_acc : 0.7762 val_loss : 0.2775 val_acc : 0.8263
# Epoch: 0501 train_loss : 0.5297 train_acc : 0.7756 val_loss : 0.2832 val_acc : 0.8280
# Epoch: 0601 train_loss : 0.5221 train_acc : 0.7810 val_loss : 0.2810 val_acc : 0.8293
# Epoch: 0701 train_loss : 0.5050 train_acc : 0.7849 val_loss : 0.2923 val_acc : 0.8303
# Epoch: 0801 train_loss : 0.5025 train_acc : 0.7892 val_loss : 0.2966 val_acc : 0.8317
# Epoch: 0901 train_loss : 0.5057 train_acc : 0.7874 val_loss : 0.2841 val_acc : 0.8327
# Epoch: 1001 train_loss : 0.4951 train_acc : 0.7936 val_loss : 0.2886 val_acc : 0.8327
# Epoch: 1101 train_loss : 0.4865 train_acc : 0.7969 val_loss : 0.2955 val_acc : 0.8317
# Epoch: 1201 train_loss : 0.4832 train_acc : 0.7992 val_loss : 0.2955 val_acc : 0.8327
# Epoch: 1301 train_loss : 0.4736 train_acc : 0.7992 val_loss : 0.3091 val_acc : 0.8307
# Epoch: 1401 train_loss : 0.4719 train_acc : 0.8005 val_loss : 0.3412 val_acc : 0.8287
# Epoch: 1501 train_loss : 0.4689 train_acc : 0.8021 val_loss : 0.3716 val_acc : 0.7887
# Epoch: 1601 train_loss : 0.4742 train_acc : 0.8046 val_loss : 0.3805 val_acc : 0.7887
# Epoch: 1701 train_loss : 0.4718 train_acc : 0.8031 val_loss : 0.3794 val_acc : 0.7897
# Epoch: 1801 train_loss : 0.4662 train_acc : 0.8038 val_loss : 0.3982 val_acc : 0.7827
# Epoch: 1901 train_loss : 0.4639 train_acc : 0.8059 val_loss : 0.3919 val_acc : 0.7920
# Epoch: 2001 train_loss : 0.4598 train_acc : 0.8072 val_loss : 0.4029 val_acc : 0.7920
# Epoch: 2101 train_loss : 0.4566 train_acc : 0.8069 val_loss : 0.4074 val_acc : 0.7907
# Epoch: 2201 train_loss : 0.4592 train_acc : 0.8067 val_loss : 0.4092 val_acc : 0.7910
# Epoch: 2301 train_loss : 0.4545 train_acc : 0.8090 val_loss : 0.4185 val_acc : 0.7897
# Epoch: 2401 train_loss : 0.4504 train_acc : 0.8100 val_loss : 0.4265 val_acc : 0.7890
# Epoch: 2501 train_loss : 0.4495 train_acc : 0.8087 val_loss : 0.4385 val_acc : 0.7890
# Epoch: 2601 train_loss : 0.4488 train_acc : 0.8090 val_loss : 0.4374 val_acc : 0.7887
# Epoch: 2701 train_loss : 0.4451 train_acc : 0.8085 val_loss : 0.4453 val_acc : 0.7497
# Epoch: 2801 train_loss : 0.4464 train_acc : 0.8092 val_loss : 0.4552 val_acc : 0.7450
# Epoch: 2901 train_loss : 0.4441 train_acc : 0.8110 val_loss : 0.4663 val_acc : 0.7423
# Epoch: 3001 train_loss : 0.4459 train_acc : 0.8115 val_loss : 0.4597 val_acc : 0.7660
# Epoch: 3101 train_loss : 0.4412 train_acc : 0.8131 val_loss : 0.4664 val_acc : 0.7443
# Epoch: 3201 train_loss : 0.4460 train_acc : 0.8156 val_loss : 0.4471 val_acc : 0.7483
# Epoch: 3301 train_loss : 0.4450 train_acc : 0.8123 val_loss : 0.4592 val_acc : 0.7430
# Epoch: 3401 train_loss : 0.4336 train_acc : 0.8151 val_loss : 0.4561 val_acc : 0.7433
# Epoch: 3501 train_loss : 0.4421 train_acc : 0.8149 val_loss : 0.4648 val_acc : 0.7413
# Epoch: 3601 train_loss : 0.4417 train_acc : 0.8172 val_loss : 0.4663 val_acc : 0.7420
# Epoch: 3701 train_loss : 0.4369 train_acc : 0.8149 val_loss : 0.4776 val_acc : 0.7403
# Epoch: 3801 train_loss : 0.4404 train_acc : 0.8136 val_loss : 0.4881 val_acc : 0.7400
# Epoch: 3901 train_loss : 0.4343 train_acc : 0.8144 val_loss : 0.4861 val_acc : 0.7423
# Epoch: 4001 train_loss : 0.4333 train_acc : 0.8146 val_loss : 0.4921 val_acc : 0.7403
# Epoch: 4101 train_loss : 0.4321 train_acc : 0.8182 val_loss : 0.4903 val_acc : 0.7417
# Epoch: 4201 train_loss : 0.4356 train_acc : 0.8174 val_loss : 0.5017 val_acc : 0.7417
# Epoch: 4301 train_loss : 0.4308 train_acc : 0.8159 val_loss : 0.5047 val_acc : 0.7417
# Epoch: 4401 train_loss : 0.4331 train_acc : 0.8182 val_loss : 0.5191 val_acc : 0.7417
# Epoch: 4501 train_loss : 0.4273 train_acc : 0.8210 val_loss : 0.5171 val_acc : 0.7420
# Epoch: 4601 train_loss : 0.4285 train_acc : 0.8203 val_loss : 0.5342 val_acc : 0.7413
# Epoch: 4701 train_loss : 0.4363 train_acc : 0.8203 val_loss : 0.5460 val_acc : 0.7417
# Epoch: 4801 train_loss : 0.4233 train_acc : 0.8228 val_loss : 0.5567 val_acc : 0.7420
# Epoch: 4901 train_loss : 0.4316 train_acc : 0.8221 val_loss : 0.5771 val_acc : 0.7400
# Optimization Finished!
# Test Accuracy: 0.79317415
# Execution time (seconds) was 796.774

# %% [markdown]
# ### Evaluate the model

# %%
# returns a compiled model
# identical to the previous one
with tf.Session() as sess:
    saver = tf.train.Saver()
    saver.restore(sess, log_files_path+'DL_Project/lstm-checkpoint')
    
    pred = sess.run(prediction, feed_dict={X: x_train, Y: y_train})    
    pred_df_train = pd.DataFrame(pred, columns=['-1', '0', '1'])
    pred_df_train['predict'] = pred_df_train.idxmax(axis=1)
    pred_df_train['true'] = pd.DataFrame(y_train, columns=['-1', '0', '1']).idxmax(axis=1)
    
    pred = sess.run(prediction, feed_dict={X: x_test, Y: y_test})    
    pred_df_test = pd.DataFrame(pred, columns=['-1', '0', '1'])
    pred_df_test['predict'] = pred_df_test.idxmax(axis=1)
    pred_df_test['true'] = pd.DataFrame(y_test, columns=['-1', '0', '1']).idxmax(axis=1)  
    
train_f1 = f1_score(pred_df_train.true, pred_df_train.predict, average=None)
test_f1 = f1_score(pred_df_test.true, pred_df_test.predict, average=None)
print (train_f1)
print (test_f1)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/macbook/Desktop/DLFall2018/codes/DL project/tensorflow-master/logsDL_Project/lstm-checkpoint
# [0.82530756 0.82337317 0.8152819 ]
# [0.03829225 0.8846325  0.02175066]

# %% [markdown]
# ### Results on training data

# %%
evaluator = MLEvaluator()
evaluator.set_pred_df(pred_df_train)
cf_mx_train = evaluator.generate_confusion_matrix()

fig = evaluator.plot_confusion_matrix(cf_mx_train.values, [-1, 0, 1])
fig = evaluator.plot_confusion_matrix(cf_mx_train.values, [-1, 0, 1], normalize=True)
fig = evaluator.plot_roc()
# Out:
# Confusion matrix, without normalization
# [[1174   11  115]
#  [ 188  930  182]
#  [ 183   18 1099]]
# Normalized confusion matrix
# [[0.90307692 0.00846154 0.08846154]
#  [0.14461538 0.71538462 0.14      ]
#  [0.14076923 0.01384615 0.84538462]]

# %% [markdown]
# ### Results on testing data

# %%
evaluator.set_pred_df(pred_df_test)
cf_mx_test = evaluator.generate_confusion_matrix()

fig = evaluator.plot_confusion_matrix(cf_mx_test.values, [-1, 0, 1])
fig = evaluator.plot_confusion_matrix(cf_mx_test.values, [-1, 0, 1], normalize=True)
fig = evaluator.plot_roc()
# Out:
# Confusion matrix, without normalization
# [[  174    11    60]
#  [ 8647 89439 14629]
#  [   22    41   164]]
# Normalized confusion matrix
# [[0.71020408 0.04489796 0.24489796]
#  [0.07671561 0.79349687 0.12978752]
#  [0.0969163  0.18061674 0.72246696]]
